# %% [markdown]
# # 2차원 데이터의 정리
#
# ## 두 데이터 사이의 관계를 나타내는 지표

# %%
import numpy as np
import pandas as pd
get_ipython().run_line_magic('precision', '3')
pd.set_option('precision', 3)

# %% [markdown]
# **두 변수 사이의 관계 측도**
# - 수치형 변수간의 관계 : Pearson's correlation
# - 순서형 변수간의 관계 : Kendall's tau, Spearman Correlation
# - 범주형 변수간의 관계 : 카이제곱 검정 - Phi correlation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **두 변수간의 관계 시각화**
# - 범주형 변수간의 관계 시각화 : 모자익플롯(Mosaic plot)
# - 수치형 변수간의 관계 시각화 : 산점도(scatter plot)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# **예제 데이터**

# %%
df = pd.read_csv('./data/ch2_scores_em.csv',
                 index_col='student number')
df.head()
# Out:
#                 english  mathematics
# student number
# 1                    42           65
# 2                    69           80
# 3                    56           63
# 4                    41           63
# 5                    57           76

# %%
import matplotlib.pyplot as plt
plt.scatter(df['english'], df['mathematics'])
plt.xlabel('english score')
plt.ylabel('mathematics score')

plt.axhline(y=df['mathematics'].mean(), color='r',
            linewidth=1,linestyle=':') # 수평선 : 수학의 평균값
plt.axvline(x=df['english'].mean(), color='r',
            linewidth=1,linestyle=':') # 수직선 : 영어의 평균값
plt.show()

# %% [markdown]
# ### 공분산(covariance)
# - 두 변수 사이의 관계성 척도
# - 예.
#     - 직사각형의 가로길이는 영어 점수의 편차, 세로는 수학 점수의 편차
#     - 공분산은 면적, 음의 면적도 가능(음의 상관)
#
#
# ![image.png](attachment:image.png)

# %%
# 각 과목의 편차 및 과목간 공분산

summary_df = df.copy()
summary_df['eng_dev.'] =\
    summary_df['english'] - summary_df['english'].mean()
summary_df['math_dev.'] =\
    summary_df['mathematics'] - summary_df['mathematics'].mean()
summary_df['productOfDev.'] =\
    summary_df['eng_dev.'] * summary_df['math_dev.']
summary_df.head()
# Out:
#                 english  mathematics  eng_dev.  math_dev.  productOfDev.
# student number
# 1                    42           65    -16.38     -13.88        227.354
# 2                    69           80     10.62       1.12         11.894
# 3                    56           63     -2.38     -15.88         37.794
# 4                    41           63    -17.38     -15.88        275.994
# 5                    57           76     -1.38      -2.88          3.974

# %%
summary_df['productOfDev.'].mean()
# 각 학생별 영어와 수학의 공분산 평균이 62.8이므로 영어와 수학은 양의 상관 관계에 있다고 볼 수 있음
# Out:
# 58.486

# %% [markdown]
# **numpy의 공분산 함수 : cov(data1, data2, ddof=)**
#
# - 반환값 : 공분산 행렬
# - 반환 행렬 중 [0,1]과 [1,0] 의 원소가 공분산 값
# \begin{pmatrix}
#   {영어,영어} & {영어,수학} \\
#   {수학,영어} & {수학,수학}
# \end{pmatrix}

# %%
cov_mat = np.cov(df['english'],df['mathematics'], ddof=0) # 모집단의 공분산
cov_mat
# Out:
# array([[94.116, 58.486],
#        [58.486, 69.386]])

# %%
cov_mat[0,1], cov_mat[1,0]
# Out:
# (58.485600000000005, 58.485600000000005)

# %% [markdown]
# **각 과목의 분산**

# %%
cov_mat[0,0] # 영어과목의 분산
# Out:
# 94.1156

# %%
cov_mat[1,1] # 수학과목의 분산
# Out:
# 69.38560000000001

# %%
np.var(df['english'],ddof=0),np.var(df['mathematics'],ddof=0)
# Out:
# (94.116, 69.386)

# %% [markdown]
# ### 상관계수
# - 공분산은 각 데이터의 단위의 제곱으로 표현되어 직관적으로 이해하기 어려움
#     - 시험 점수간의 공분산(점수X점수), 키와 점수간의 공분산 (cm X 점수)
# - 단위에 의존하지 않는 상관성을 나타내는 지표
# - 상관계수는 공분산을 각 데이터의 표준편차로 나누어 단위에 의존하지 않음
#
# ![image.png](attachment:image.png)
#
# - 양의 상관은 1에 가까워지고, 음의 상관은 -1에 가까워지고, 무상관은 0

# %%
# 수식으로 상관계수 계산
np.cov(df['english'], df['mathematics'], ddof=0)[0, 1] /\
    (np.std(df['english']) * np.std(df['mathematics']))
# Out:
# 0.7237414863069245

# %% [markdown]
# **상관계수 함수(np.corrcoef(x,y) / df.corr())**

# %%
np.corrcoef(df['english'],df['mathematics'])
# Out:
# array([[1.   , 0.724],
#        [0.724, 1.   ]])

# %% [markdown]
# **pandas.DataFrame.corr() 함수**

# %%
# pandas.DataFrame.corr() 함수 적용
df.corr()

# %% [markdown]
# - 양의 상관은 1에 가까워지고, 음의 상관은 -1에 가까워지고, 무상관은 0
# - 상관계수가 -1일 때와 1일 때 데이터는 완전히 직선상에 놓임
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2차원 데이터의 시각화
#
# ### 산점도

# %%
import matplotlib.pyplot as plt

get_ipython().run_line_magic('matplotlib', 'inline')

# %%
# 산점도
plt.scatter(df['english'],df['mathematics'] )
plt.xlabel('english')
plt.ylabel('mathematics')
plt.show()

# %% [markdown]
# ### 회귀직선

# %%
# 계수β_0와β_1를 구한다(기울기와 절편)
poly_fit = np.polyfit(df['english'],df['mathematics'], 1)

# β_0+β_1 x를 반환하는 함수를 작성
poly_1d = np.poly1d(poly_fit)

# 직선을 그리기 위한 x좌표
xs = np.linspace(df['english'].min(), df['english'].max())

# xs에 대응하는 y좌표
ys = poly_1d(xs)

plt.xlabel('english')
plt.ylabel('mathematics')
plt.scatter(df['english'],df['mathematics'], label='score')
plt.plot(xs, ys, color='gray',
        label=f'{poly_fit[1]:.2f}+{poly_fit[0]:.2f}x')

# 범례의 표시
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# ### 히트맵
#
# - 히스토그램의 2차원 버전으로 색을 이용해 표현하는 그래프
# - 영어 점수 35점부터 80점, 수학 점수 55점부터 95점까지 5점 간격

# %%
c = plt.hist2d(df['english'],df['mathematics'],
          bins=(9,8), range=[(35,80),(55,95)])
plt.xlabel('english')
plt.ylabel('mathematics')
plt.xticks(c[1])
plt.yticks(c[2])

plt.colorbar(c[3])
plt.show()
